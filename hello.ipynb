# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6
#
# Biasa kita tulis komen di sini
#
# >

# %%
print("Halo dunia")
# Out:
# Halo dunia

# %%
suatu_variabel = "Kosong Adalah isi"

suatu_variabel
# Out:
# 'Kosong Adalah isi'

# %%
print('Hello')
# Out:
# Hello
